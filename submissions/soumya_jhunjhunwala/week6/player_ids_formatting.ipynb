# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import shap
from sklearn import preprocessing
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import cross_val_score
from sklearn.decomposition import PCA
from sklearn.feature_selection import RFECV
from sklearn.feature_selection import RFE
from xgboost import XGBRegressor
from pyswarms.single.global_best import GlobalBestPSO

# %%
df_original_data = pd.read_csv('mw_pw_profiles.csv')
print("Original Data")
df_original_data
# Out:
# Original Data
#        player_id match_id  gender  balls_per_over  start_date  \
# 0       00015688  1158348  female               6  2018-08-21
# 1       00015688  1182644  female               6  2019-05-05
# 2       00015688  1275107  female               6  2021-09-09
# 3       00015688  1275113  female               6  2021-09-15
# 4       00015688  1275125  female               6  2021-09-14
# ...          ...      ...     ...             ...         ...
# 416707  fffa744b  1473475    male               6  2025-04-20
# 416708  fffa744b  1473478    male               6  2025-04-23
# 416709  fffa744b  1473482    male               6  2025-04-27
# 416710  fffa744b  1473487    male               6  2025-05-01
# 416711  fffa744b  1473493    male               6  2025-05-06
#
#                                               series_name match_type  \
# 0        Botswana Cricket Association Women's T20I Series        T20
# 1       ICC Women's T20 World Cup Africa Region Qualifier        T20
# 2       ICC Women's T20 World Cup Africa Region Qualifier        T20
# 3       ICC Women's T20 World Cup Africa Region Qualifier        T20
# 4       ICC Women's T20 World Cup Africa Region Qualifier        T20
# ...                                                   ...        ...
# 416707                              Indian Premier League        T20
# 416708                              Indian Premier League        T20
# 416709                              Indian Premier League        T20
# 416710                              Indian Premier League        T20
# 416711                              Indian Premier League        T20
#
#             name_x  runs_scored  player_out  ...  key_pulse  key_pulse_2  \
# 0           M King           10           1  ...        NaN          NaN
# 1           M King            8           1  ...        NaN          NaN
# 2           M King            1           0  ...        NaN          NaN
# 3           M King            0           0  ...        NaN          NaN
# 4           M King            1           1  ...        NaN          NaN
# ...            ...          ...         ...  ...        ...          ...
# 416707  Naman Dhir            0           0  ...        NaN          NaN
# 416708  Naman Dhir            0           0  ...        NaN          NaN
# 416709  Naman Dhir           25           0  ...        NaN          NaN
# 416710  Naman Dhir            0           0  ...        NaN          NaN
# 416711  Naman Dhir            7           1  ...        NaN          NaN
#
#         full_name  batting_style  bowling_style  playing_role  teams  \
# 0             NaN            NaN            NaN           NaN     []
# 1             NaN            NaN            NaN           NaN     []
# 2             NaN            NaN            NaN           NaN     []
# 3             NaN            NaN            NaN           NaN     []
# 4             NaN            NaN            NaN           NaN     []
# ...           ...            ...            ...           ...    ...
# 416707        NaN            NaN            NaN           NaN     []
# 416708        NaN            NaN            NaN           NaN     []
# 416709        NaN            NaN            NaN           NaN     []
# 416710        NaN            NaN            NaN           NaN     []
# 416711        NaN            NaN            NaN           NaN     []
#
#        fantasy_score_batting  fantasy_score_bowling  fantasy_score_total
# 0                          5                      8                   17
# 1                          3                      0                    7
# 2                          1                      0                    5
# 3                          0                      0                    4
# 4                         -5                      0                   -1
# ...                      ...                    ...                  ...
# 416707                     0                      0                    4
# 416708                     0                      8                   12
# 416709                    37                      8                   49
# 416710                     0                      0                    4
# 416711                     6                      8                   18
#
# [416712 rows x 58 columns]

# %%
df_original_data.columns
# Out:
# Index(['player_id', 'match_id', 'gender', 'balls_per_over', 'start_date',
#        'series_name', 'match_type', 'name_x', 'runs_scored', 'player_out',
#        'balls_faced', 'fours_scored', 'sixes_scored', 'catches_taken',
#        'run_out_direct', 'run_out_throw', 'stumpings_done', 'out_kind',
#        'dot_balls_as_batsman', 'order_seen', 'balls_bowled', 'runs_conceded',
#        'wickets_taken', 'bowled_done', 'lbw_done', 'maidens',
#        'dot_balls_as_bowler', 'player_team', 'opposition_team', 'name_y',
#        'unique_name', 'key_bcci', 'key_bcci_2', 'key_bigbash', 'key_cricbuzz',
#        'key_cricheroes', 'key_crichq', 'key_cricinfo', 'key_cricinfo_2',
#        'key_cricinfo_3', 'key_cricingif', 'key_cricketarchive',
#        'key_cricketarchive_2', 'key_cricketworld', 'key_nvplay',
#        'key_nvplay_2', 'key_opta', 'key_opta_2', 'key_pulse', 'key_pulse_2',
#        'full_name', 'batting_style', 'bowling_style', 'playing_role', 'teams',
#        'fantasy_score_batting', 'fantasy_score_bowling',
#        'fantasy_score_total'],
#       dtype='object')

# %%
df_original_data['unique_name'].nunique()
# Out:
# 11769

# %%
df_original_data['unique_name'].head(20)
# Out:
# 0          M King
# 1          M King
# 2          M King
# 3          M King
# 4          M King
# 5       M Mwamadi
# 6       M Mwamadi
# 7       M Mwamadi
# 8       M Mwamadi
# 9       M Mwamadi
# 10      M Mwamadi
# 11      M Mwamadi
# 12     Hongki Kim
# 13    M Tarimiala
# 14    M Tarimiala
# 15    M Tarimiala
# 16    M Tarimiala
# 17    M Tarimiala
# 18    M Tarimiala
# 19    M Tarimiala
# Name: unique_name, dtype: object

# %%
df_original_data['unique_name'] = (
    df_original_data['unique_name']
      .str.strip()           # leading/trailing spaces
      .str.replace(r'\s+', ' ', regex=True)   # double spaces, tabs, newlines
      .str.title()           # uniform capitalisation (optional)
)

# %%
df_original_data['unique_name'].nunique()
# Out:
# 11769

# %%
df_original_data['player_id'].nunique()
# Out:
# 11771

# %%
name_to_many_ids = (
    df_original_data.groupby('unique_name')['player_id']
      .agg(ids=lambda s: sorted(s), id_count='nunique')
      .query('id_count > 1')        # keep only the problematic rows
      .reset_index()
      .sort_values('id_count', ascending=False)
)

print(f"Problematic full_name rows: {len(name_to_many_ids)}")
# Out:
# Problematic full_name rows: 0

# %%
df_original_data['start_date'] = pd.to_datetime(df_original_data['start_date'], errors='coerce')

df_original_data.sort_values(by=['start_date'], inplace=True)
df_original_data.reset_index(drop=True, inplace=True)

# %%
cutoff_date = pd.to_datetime('2023-01-01')

df_latest = df_original_data[df_original_data['start_date'] >= cutoff_date]

# %%
mask_aus = (
    df_latest['player_team']
      .astype(str)           # in case the column has NaNs
      .str.strip()           # trim spaces
      .str.casefold()        # robust lower‑case
      .eq('australia')       # True/False Series
)

# %%
aus_players = (
    df_latest.loc[mask_aus, ['unique_name', 'player_id']]
      .drop_duplicates()          # keep unique rows only
      .sort_values('unique_name')      # nice alphabetical order
      .reset_index(drop=True)
)

# %%
aus_players.head(55)
# Out:
#         unique_name player_id
# 0         A Gardner  bc969efb
# 1            A King  83558266
# 2      A Sutherland  65d9b6b6
# 3           A Zampa  14f96089
# 4           Ac Agar  a2421394
# 5          Aj Healy  321644de
# 6         Aj Turner  ff1e12a0
# 7         Am Hardie  d405c0d5
# 8          At Carey  69d03465
# 9      Bj Dwarshuis  e1b9f3a9
# 10       Bj Webster  56b93d46
# 11        Bl Mooney  52d1dbc8
# 12     Br Mcdermott  c41043e6
# 13       C Connolly  fe366f34
# 14          C Green  eaa76d3c
# 15         Cj Green  19b9f399
# 16          D Brown  2e81be88
# 17        Da Warner  dcce6f09
# 18         Ea Perry  be150fc8
# 19           G Voll  5c30d455
# 20        G Wareham  f0b4e47d
# 21       Gj Maxwell  b681e71e
# 22        Gm Harris  72166006
# 23         H Graham  99812d10
# 24  J Fraser-Mcgurk  9b6e1b3f
# 25      Jl Jonassen  0475a86b
# 26   Jp Behrendorff  4933f499
# 27        Jp Inglis  989889ff
# 28     Jr Hazlewood  03806cf8
# 29      Jr Philippe  39086549
# 30         Kj Garth  0b69a844
# 31    Kw Richardson  dfc4d8b5
# 32        L Cheatle  275dff85
# 33        Lr Morris  b08e58e2
# 34    M Labuschagne  fa433be6
# 35         Ma Starc  3fb19989
# 36         Mg Neser  0164b064
# 37        Ml Schutt  17608a6f
# 38       Mm Lanning  27e003ce
# 39     Mp Kuhnemann  7b953689
# 40       Mp Stoinis  d9273ee7
# 41         Mr Marsh  3d8feaf8
# 42          Ms Wade  afa7e784
# 43       Mt Renshaw  218d4d78
# 44         Mw Short  a90e53ec
# 45     Na Mcsweeney  e94d2d50
# 46          Nm Lyon  96a6a7ad
# 47         Nt Ellis  9eb1455b
# 48     P Litchfield  4e6ef14f
# 49       Pj Cummins  ded9240e
# 50    Psp Handscomb  ada15e88
# 51      Rp Meredith  64775749
# 52        S Konstas  3c34c9e1
# 53       S Molineux  99e23670
# 54        Sa Abbott  1a2676c5

# %%
australlia_playing_players = ['Nm Lyon', 'Ma Starc', 'C Green', 'Pj Cummins', 'At Carey', 'Bj Webster', 'Jp Inglis', 'Ut Khawaja', 'Mp Kuhnemann', 'Tm Head', 'Sa Abbott', 'Sm Boland', 'Spd Smith', 'Jr Hazlewood', 'S Konstas', 'M Labuschagne']

filtered = aus_players.loc[aus_players['unique_name'].isin(australlia_playing_players)]

# %%
filtered = filtered.reset_index(drop=True)

# %%
filtered
# Out:
#       unique_name player_id
# 0        At Carey  69d03465
# 1      Bj Webster  56b93d46
# 2         C Green  eaa76d3c
# 3       Jp Inglis  989889ff
# 4    Jr Hazlewood  03806cf8
# 5   M Labuschagne  fa433be6
# 6        Ma Starc  3fb19989
# 7    Mp Kuhnemann  7b953689
# 8         Nm Lyon  96a6a7ad
# 9      Pj Cummins  ded9240e
# 10      S Konstas  3c34c9e1
# 11      Sa Abbott  1a2676c5
# 12      Sm Boland  d167edd3
# 13      Spd Smith  30a45b23
# 14        Tm Head  12b610c2
# 15     Ut Khawaja  331ea488

# %%
filtered.to_csv('australlia_players.csv', index=False)

# %%
mask_aus = (
    df_latest['player_team']
      .astype(str)           # in case the column has NaNs
      .str.strip()           # trim spaces
      .str.casefold()        # robust lower‑case
      .eq('west indies')       # True/False Series
)

# %%
wi_players = (
    df_latest.loc[mask_aus, ['unique_name', 'player_id']]
      .drop_duplicates()          # keep unique rows only
      .sort_values('unique_name')      # nice alphabetical order
      .reset_index(drop=True)
)

# %%
wi_players
# Out:
#    unique_name player_id
# 0   A Athanaze  58c2fac4
# 1    A Munisar  a811cb83
# 2   Aa Alleyne  4b0e3049
# 3    Aa Jangoo  88626ed2
# 4   Ad Russell  bbd41817
# ..         ...       ...
# 78    T Holder  41fd2907
# 79   Ta Imlach  f0f8f105
# 80   Tj Bishop  c68554a6
# 81    Y Cariah  78bb68d4
# 82     Z James  816af623
#
# [83 rows x 2 columns]

# %%
wi_players.head(60)
# Out:
#       unique_name player_id
# 0      A Athanaze  58c2fac4
# 1       A Munisar  a811cb83
# 2      Aa Alleyne  4b0e3049
# 3       Aa Jangoo  88626ed2
# 4      Ad Russell  bbd41817
# 5    Ads Fletcher  1bae756b
# 6       Aj Hosein  4d7f517e
# 7    Akeem Jordan  77bf0483
# 8       As Joseph  b0946605
# 9    Ass Fletcher  42d9dd09
# 10       B Cooper  ac0edb42
# 11        Ba King  7fca84b7
# 12       Ca Henry  75820733
# 13      Cn Nation  639000b6
# 14      Cs Fraser  fb9a8cc3
# 15       D Joseph  6d7ca3e6
# 16      Dc Drakes  34b332d3
# 17     Djs Dottin  53bee17f
# 18        E Lewis  0ebfb1ad
# 19       Fa Allen  b52ffbbd
# 20        G Motie  97bdec3d
# 21    Hk Matthews  d32cf49a
# 22       Hr Walsh  1ac2a995
# 23       J Andrew  6b0db726
# 24    J Blackwood  c3b93a03
# 25       J Blades  af4a9a0a
# 26      J Charles  09a9d073
# 27     J Da Silva  bab78fa2
# 28      J Glasgow  a2632c7c
# 29    Ja Warrican  cc23e91e
# 30     Jnt Seales  ded9ff1e
# 31      Jo Holder  0f721006
# 32     Jp Greaves  74d12124
# 33    K Ramharack  321c980e
# 34      K Schultz  6900060d
# 35     K Sinclair  314642ed
# 36      Kaj Roach  78eb4223
# 37      Kar Hodge  49dc9cb4
# 38  Kc Brathwaite  7d5af2ea
# 39       Kma Paul  75224f22
# 40      Kr Mayers  73c18486
# 41   Ksa Mckenzie  2b8f219a
# 42       Ku Carty  6020a3c6
# 43      Ky Ottley  50a92895
# 44        M Louis  1d8c298b
# 45       M Mangru  b9fec7a5
# 46     Mj Mindley  b88fa6fe
# 47       Mw Forde  83d17bbc
# 48       N Pooran  3241e3fd
# 49     Nk Crafton  6fa7dcd8
# 50       O Thomas  c6097d68
# 51       Oc Mccoy  529eb9e0
# 52       Of Smith  23cca426
# 53       Q Joseph  d6164dc0
# 54       R Powell  650d5e49
# 55     R Shepherd  c5aef772
# 56      Ra Reifer  d7725664
# 57       Rl Chase  3feda4fa
# 58   Rrs Cornwall  c4d9634c
# 59    Rs Williams  406de451

# %%
wi_players.tail(20)
# Out:
#       unique_name player_id
# 63      Sc Selman  c29ada99
# 64        Sd Hope  1fc6ef83
# 65  Se Rutherford  d014d5ac
# 66       Sj Bruce  aeccf5cc
# 67    Sk Springer  4175d211
# 68     So Hetmyer  48a1d7b7
# 69  Song Yangyang  cf33e1ce
# 70      Sr Taylor  92cf79a8
# 71     Ss Connell  2f9a6bd1
# 72    Ss Cottrell  a1d053dd
# 73    Ss Grimmond  6bebf334
# 74     Ssj Brooks  977b841a
# 75     St Gabriel  d9609443
# 76  T Chanderpaul  80c6ed7d
# 77        T Hinds  45a62071
# 78       T Holder  41fd2907
# 79      Ta Imlach  f0f8f105
# 80      Tj Bishop  c68554a6
# 81       Y Cariah  78bb68d4
# 82        Z James  816af623

# %%
wi_playing_players = ['Ba King','Ku Carty','Kc Brathwaite','M Louis','Jp Greaves', 'Rl Chase', 'Sd Hope','Ta Imlach','As Joseph', 'Jnt Seales', 'Ja Warrican', 'S Joseph']

# %%
filtered2 = wi_players.loc[wi_players['unique_name'].isin(wi_playing_players)]

# %%
filtered2 = filtered2.reset_index(drop=True)

# %%
filtered2
# Out:
#       unique_name player_id
# 0       As Joseph  b0946605
# 1         Ba King  7fca84b7
# 2     Ja Warrican  cc23e91e
# 3      Jnt Seales  ded9ff1e
# 4      Jp Greaves  74d12124
# 5   Kc Brathwaite  7d5af2ea
# 6        Ku Carty  6020a3c6
# 7         M Louis  1d8c298b
# 8        Rl Chase  3feda4fa
# 9        S Joseph  97290faf
# 10        Sd Hope  1fc6ef83
# 11      Ta Imlach  f0f8f105

# %%
filtered2.to_csv('west_indies_players.csv', index=False)
